# %%
import sys
sys.path.append("../tools")
import drm

# %%
with open("../data/Deus Ex 3 - Director's Cut/files/bigfile.filelist") as f:
    names = f.read().split("\n")

with open("../data/Deus Ex 3 - Director's Cut/files/more.filelist") as f:
    names.extend(f.read().split("\n"))

assert names[0][0] == ";" # unimportant line
del names[0:1]

# %%
bigfile = drm.BigFile("../bigfiles/BIGFILE.000")
# Out:
# opened ../bigfiles/BIGFILE.000
# opened ../bigfiles/BIGFILE.001
# opened ../bigfiles/BIGFILE.002
# opened ../bigfiles/BIGFILE.003
# opened ../bigfiles/BIGFILE.004
# opened ../bigfiles/BIGFILE.005
# opened ../bigfiles/BIGFILE.006
# opened ../bigfiles/BIGFILE.007
# opened ../bigfiles/BIGFILE.008

# %%
print(len(names))
crchashes = set(bigfile.entries.keys())
knownhashes = {drm.crc32r(name.encode("utf-8")) for name in names}
print("{}/{}".format(len(crchashes & knownhashes), len(crchashes)))
# Out:
# 33185
# 33182/33887

# %%
missing = []

for crc, payloads in bigfile.entries.items():
    if crc in knownhashes: continue

    # assume they all have the same type
    # so looking at the first is sufficient
    offset, size, lang = payloads[0]
    blob = bigfile.get_slice(offset, size)
    missing.append((crc, blob))

# %%
missing_fxanim = []
missing_fsb4 = []
missing_cdrm = []
missing_mus = []
missing_enic = []
missing_scaleform = []
missing_unknown = []

for crc, blob in missing:
    magic = blob[0:4]
    fxanim = b"FxAnim" in blob    # pc-w\audio\streams\vo\eng\ ... .mul
    fsb4 = b"FSB4" in blob        # pc-w\audio or music\ .mul .sam
    cdrm = magic == b"CDRM"       # everything
    mus = magic == b"Mus!"        # pc-w\music\ ... .mus
    enic = b"ENIC" in blob        # pc-w\art\cinematics\cinstream\ ... .mul
    scaleform = magic == b"CRID"  # pc-w/design_database/videos/cinematics/final_cinematics/cut_01_shq0_2_jaronnamir/dxni_110_v07-jaronnamir_assembly.usm

    #print("{:08x} {} {} {} {} {} {}".format(crc, fxanim, fsb4, cdrm, mus, enic, scaleform))
    
    if fxanim: missing_fxanim.append(crc)
    if fsb4: missing_fsb4.append(crc)
    if cdrm: missing_cdrm.append(crc)
    if mus: missing_mus.append(crc)
    if enic: missing_enic.append(crc)
    if scaleform: missing_scaleform.append(crc)
    if not (fxanim or fsb4 or cdrm or mus or enic or scaleform): missing_unknown.append(crc)

def print_group(header, entries):
    if len(entries) == 0: return
    print(header, len(entries))
    for entry in entries:
        print("{:08x}".format(entry))
    print()

# print_group("fxanim", missing_fxanim) # 89 entries
# print_group("fsb4", missing_fsb4) # 554 entries
# print_group("cdrm", missing_cdrm) # 143 entries
print_group("mus", missing_mus) # 0 entries
print_group("enic", missing_enic) # 1 entry
print_group("scaleform", missing_scaleform) # 1 entry
print_group("unknown", missing_unknown) # 8 entries
# Out:
# enic 1
# 24229121
#
# scaleform 1
# 218fe0b6
#
# unknown 8
# 0ff4b389
# 119ce2ca
# 341a6bb9
# 9c9d39cb
# b9098414
# b9dd84ae
# c246e0cc
# ea6cb8a4

# %% [markdown]
# # Unidentified file: 0ff4b389
# This seems to descripe an animation related statemachine

# %%
print(dict(missing)[0x0ff4b389].decode("utf-8"))
# Out:
# 1,91
# 1,uberobject_playanim
# 2,cover_transitiondone
# 3,cover_tochangefacing
# 4,movement_loopdone
# 5,cover_toswap
# 6,movement_transitiondone
# 7,weapon_transitiondone
# 8,weapon_reload_interrupt
# 9,weapon_fromwielding
# 10,weapon_toholster
# 11,weapon_todraw
# 12,weapon_aimtoreload
# 13,weapon_tofire
# 14,weapon_toreload
# 15,onskipline
# 16,onconversationgesturenonadditive
# 17,ongesturedone
# 18,default_hit
# 19,idleloop
# 20,onanimdone
# 21,onnpcsayline
# 22,onnpcintrodone
# 23,cancelhit
# 24,onconversationbodyanim
# 25,onintrodone
# 26,playeraction_done
# 27,knockdown
# 28,ongetup
# 29,onstopallactions
# 30,fullbody_hit_reaction
# 31,fullbody_hit_interrupt
# 32,genericaction_enter
# 33,genericaction_leave
# 34,onconversationexit
# 35,onconversationenter
# 36,simpleaction_enter
# 37,simpleaction_leave
# 38,simpleaction_interrupt
# 39,hit_emp_done
# 40,hitreactionmedium
# 41,onhitreactiondone
# 42,hitreaction
# 43,on_hit_emp
# 44,onreorientdone
# 45,onclaymoredone
# 46,ragdolldriveend
# 47,wakeupragdoll
# 48,death_enter
# 49,grenadepanic_leave
# 50,onstumblingdone
# 51,onrevive
# 52,impale
# 53,stun
# 54,takedown_stun
# 55,stun_exit
# 56,death_enter_crouched
# 57,unconscious
# 58,smartmovement_trigger
# 59,smartmovement_overlaytrigger
# 60,fullbody_hit_leave
# 61,onlaunchdone
# 62,deactivate
# 63,deathanimtoragdoll
# 64,unarmed_done
# 65,genericaction_autochain
# 66,cover_tohide
# 67,cover_tocorneraim
# 68,cover_tocornerhide
# 69,cover_tooveraim
# 70,mine_toreadytodetect
# 71,mine_todeactivating
# 72,mine_toenemydetected
# 73,mine_todeactivated
# 74,kneetostand_enter
# 75,kneetostand_leave
# 76,onconversationgestureadditive
# 77,bungee_toland
# 78,cover_tocornerblindfire
# 79,cover_tooverblindfire
# 80,ladder_idletoleavetop
# 81,ladder_idletomoveup
# 82,ladder_idletomovedown
# 83,ladder_idletoleavebottom
# 84,weapon_fromdraw
# 85,weapon_drawntoholstered
# 86,weapon_holsteredtodrawn
# 87,hitreactiondone
# 88,weapon_aimtofire
# 89,weapon_stopfire
# 90,ondead
# 91,ragdolltogetuptransition

# %% [markdown]
# # Unidentified file: 119ce2ca
# An XML file describing the kind of build. The strings "patches" and "switches" do not appear in the game binary so it's unlikely this file is used by the game.

# %%
print(dict(missing)[0x119ce2ca].decode("utf-8"))
# Out:
# <dx3>
#   <Version>2.0.779</Version>
#   <Content>160928</Content>
#   <patches>
#     <Item Name="isPatch" Value="0"/>
#     <Item Name="patchCode" Value=""/>
#     <Item Name="patchContent" Value=""/>
#   </patches>
#   <switches>
#     <Item Name="buildCode" Value="1"/>
#     <Item Name="buildContent" Value="1"/>
#     <Item Name="cleanBuildCode" Value="1"/>
#     <Item Name="depFileParser" Value="1"/>
#     <Item Name="deploySymbols" Value="1"/>
#     <Item Name="buildLocalized" Value="1"/>
#     <Item Name="analyzeResources" Value="1"/>
#     <Item Name="createPs3Iso" Value="1"/>
#     <Item Name="createBigFile" Value="1"/>
#     <Item Name="deployQA" Value="1"/>
#     <Item Name="deployDev" Value="1"/>
#     <Item Name="triggerDemo" Value="1"/>
#     <Item Name="applyCheckpoint" Value="1"/>
#   </switches>
# </dx3>

# %% [markdown]
# # Unidentified file: 341a6bb9
# Unsure of the purpose, the names are of .drm files but not all of them actually exist in the DRM file.
# `pc-w\base_alarm.drm` for example doesn't exist.

# %%
print(dict(missing)[0x341a6bb9].decode("utf-8")[:3000])
# Out:
# 4,490
# 1,generalbank,firstobjects,generalbank
# 2,globalsoundinfo,firstobjects
# 3,globaldebuginfo,firstobjects,globaldebuginfo
# 4,globalaniminfo,firstobjects,globalaniminfo
# 5,globalscaleformdatabase,firstobjects
# 6,globaloutershell,firstobjects,globaloutershell
# 7,globaldlcoutershell,firstobjects,globaldlcoutershell
# 8,globaldlcinfo,firstobjects,globaldlcinfo
# 9,globaldatabase,firstobjects,globaldatabase
# 10,globaldlc,firstobjects,globaldlc
# 11,globalscripting,firstobjects
# 12,player_everyman,firstobjects,globalplayerinfo
# 13,globalplayerinfo,firstobjects,globalplayerinfo
# 14,particle,firstobjects
# 15,watervolume,firstobjects
# 16,globalloading,firstobjects,globalloading
# 17,globalsmartscripts,firstobjects
# 18,cinematic_adamjensen_commando,cinematic_adamjensen_commando,s_scn_cut_omg_thearrival_sin_omega_exterior
# 19,the_pod,s_scn_cut_omg_thearrival_sin_omega_exterior,the_pod
# 20,deferred_spot_rimlight,deferred_spot_rimlight,s_scn_global_light_conv_sin_omega_lab_biomec,s_scn_global_light_conv_sin_omega_lab_gen
# 21,deferred_fast_omni_90d,deferred_fast_omni_90d,dlc_weapon_burke_revolver_equip,dlc_weapon_burke_revolver_npc,elevator_ranch_lab_a,fx_squib_concussion_a,fx_squib_concussion_mine_a,fx_squib_emp_a,fx_squib_emp_mine_a,fx_squib_frag_a,fx_squib_frag_a_npc,fx_squib_frag_mine_a,fx_squib_turret_destroyed,globalloading,laserbeam,ogre_black_a,ogre_black_b,s_scn_global_light_conv_sin_omega_lab_biomec,sin_omega_exterior,sin_omega_lab_biomec,sin_omega_lab_gen,sin_omegaexterior_mediumsentry_a,sin_omegaexterior_mediumsentry_c,weapon_combatrifle_npc,weapon_heavyrifle_npc,weapon_machinepistol_equip,weapon_machinepistol_npc,weapon_machinepistol_upgraded_equip,weapon_peps_equip,weapon_pistol_npc,weapon_revolver_equip,weapon_revolver_npc,weapon_revolver_upgraded_equip,weapon_shotgun_npc,weapon_sniperrifle_npc
# 22,deferred_fast_spot_90d,ao_ranch_sas_a,deferred_fast_spot_90d,globalloading,s_scn_global_light_conv_sin_omega_lab_gen,sin_omega_exterior,sin_omega_lab_biomec,sin_omega_lab_gen
# 23,deferredvolcoronas,ao_ranch_sas_a,base_camera,camera_security_a,deferredvolcoronas,dlc_weapon_rocketlauncher_equip,fx_squib_concussion_a,fx_squib_concussion_mine_a,fx_squib_emp_a,fx_squib_emp_mine_a,fx_squib_frag_a,fx_squib_frag_a_npc,fx_squib_frag_mine_a,fx_squib_sentry_death,fx_squib_turret_destroyed,globalloading,human_player,jensen_dlc,laserbeam,ogre_black_a,ogre_black_b,s_scn_global_light_conv_sin_omega_lab_gen,sin_omega_exterior,sin_omega_lab_biomec,sin_omega_lab_gen,sin_omegaexterior_mediumsentry_a,sin_omegaexterior_mediumsentry_c,sneaker_black_a,sneaker_white_a,sneaker_white_b,television_large,thrownproj_frag,thrownproj_unlocking_device,turret_floor,weapon_laserrifle_equip,weapon_rocketlauncher_equip,weapon_rocketlauncher_upgraded_equip
# 24,thrown_remote_detonated_world,s_scn_global_preorder_premiumpack_sin_omega_exterior,thrown_remote_detonated_world
# 25,weapon_grenadelauncher_ammo_world,s_scn_global_preorder_premiumpack_sin_omega_exterior,weapon_grenadelauncher_ammo

# %%
import re
numeric = re.compile("\d+")
lines = dict(missing)[0x341a6bb9].decode("utf-8").replace("\r\n", "\n").split("\n")
pieces = {piece for line in lines for piece in line.split(",")}
pieces = {piece for piece in pieces if piece != "" and not numeric.match(piece)}
for piece in pieces:
    if piece[0] == "\\":
        path = "pc-w" + piece + ".drm"
    else:
        path = "pc-w\\" + piece + ".drm"
    crc = drm.crc32r(path.encode("utf-8"))
    if crc not in crchashes: # find those not in the BIGFILE
        print(path)
# Out:
# pc-w\base_automatic_animated_door.drm
# pc-w\base_alarm_dispatcher.drm
# pc-w\firstobjects.drm
# pc-w\base_tv_screen.drm
# pc-w\base_swinging_dbl_door.drm
# pc-w\base_turret.drm
# pc-w\base_security_door.drm
# pc-w\base_searchable.drm
# pc-w\base_computer_shopping.drm
# pc-w\base_faridah_chopper.drm
# pc-w\base_computer.drm
# pc-w\base_searchable_animated.drm
# pc-w\base_breakable_window.drm
# pc-w\base_external_disc.drm
# pc-w\base_laserbeam.drm
# pc-w\base_playanim_ontrigger.drm
# pc-w\base_alarm.drm
# pc-w\base_alarm_panel.drm
# pc-w\base_player_interact_door.drm
# pc-w\base_news_reader.drm
# pc-w\base_keypad.drm
# pc-w\base_punchtroughwall_spawndebris.drm
# pc-w\base_ireader.drm
# pc-w\base_dedicated_terminal.drm
# pc-w\base_generic_switch.drm
# pc-w\base_bee_chopper.drm
# pc-w\base_swinging_door.drm
# pc-w\base_dstr_fireextinguisher.drm
# pc-w\base_call_elevator.drm
# pc-w\base_auto_horizontal_sliding_dbl_door.drm

# %% [markdown]
# # Unidentified file: 9c9d39cb
# Various filenames

# %%
print(dict(missing)[0x9c9d39cb].decode("utf-8")[:10000])
# Out:
# 1,17535
# 1,admd://d:\dx3dlc-pc\area\scenarios\scn_cut_omg_thearrival\overlays\s_scn_cut_omg_thearrival_sin_omega_exterior
# 2,d:\dx3dlc-pc\area\scenarios\scn_cut_omg_thearrival\overlays\s_scn_cut_omg_thearrival_sin_omega_exterior.dat
# 3,area/scenarios/scn_cut_omg_thearrival/overlays/s_scn_cut_omg_thearrival_sin_omega_exterior/s_scn_cut_omg_thearrival_sin_omega_exterior
# 4,d:\dx3dlc-pc\art\fsfx\basiclvl\underwater.fsfx
# 5,game/script/core/core/clock
# 6,game/script/core/core/corebase
# 7,game/script/core/core/messagechannel
# 8,game/script/core/core/rotation
# 9,game/script/core/core/symbol
# 10,game/script/core/core/vector
# 11,game/script/game/game/action
# 12,game/script/game/game/actiontype
# 13,game/script/game/game/actor
# 14,game/script/game/game/actorsensor
# 15,game/script/game/game/actortunedata
# 16,game/script/game/game/actortype
# 17,game/script/game/game/aimingcontroller
# 18,game/script/game/game/anchor
# 19,game/script/game/game/animation
# 20,game/script/game/game/animgraphrtvalue
# 21,game/script/game/game/animgraphtransition
# 22,game/script/game/game/barkevent
# 23,game/script/game/game/binaryreader
# 24,game/script/game/game/binarywriter
# 25,game/script/game/game/controller
# 26,game/script/game/game/conversation
# 27,game/script/game/game/conversationenum
# 28,game/script/game/game/damagetype
# 29,game/script/game/game/disturbanceseverityenum
# 30,game/script/game/game/disturbancetypeenum
# 31,game/script/game/game/dynamicfragment
# 32,game/script/game/game/enumaidisturbancedetailsdtp
# 33,game/script/game/game/gamebase
# 34,game/script/game/game/gameglobalsbase
# 35,game/script/game/game/goal
# 36,game/script/game/game/heightcontroller
# 37,game/script/game/game/hostedanimstategraph
# 38,game/script/game/game/instance
# 39,game/script/game/game/instanceref
# 40,game/script/game/game/instancestatus
# 41,game/script/game/game/inventoryitem
# 42,game/script/game/game/locomotioncontroller
# 43,game/script/game/game/lookat
# 44,game/script/game/game/markup
# 45,game/script/game/game/modelmarker
# 46,game/script/game/game/objectref
# 47,game/script/game/game/occupation
# 48,game/script/game/game/padshock
# 49,game/script/game/game/pickup
# 50,game/script/game/game/rangesensor
# 51,game/script/game/game/smartbase
# 52,game/script/game/game/smartcontext
# 53,game/script/game/game/smartfloat
# 54,game/script/game/game/smartscript
# 55,game/script/game/game/sound
# 56,game/script/game/game/soundendtype
# 57,game/script/game/game/speed
# 58,game/script/game/game/stance
# 59,game/script/game/game/stickybool
# 60,game/script/game/game/stickyfloat
# 61,game/script/game/game/stickyint
# 62,game/script/game/game/terraingroup
# 63,game/script/game/game/unit
# 64,game/script/game/game/unitref
# 65,game/script/game/game/waypointnode
# 66,d:\dx3dlc-pc\object\characters\base\mesh\_kit_systems_\eyes\adam_eye.mtl
# 67,d:\dx3dlc-pc\object\characters\base\mesh\_shared_parts\eye\textures\lens.mtl
# 68,d:\dx3dlc-pc\object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_arms.mtl
# 69,d:\dx3dlc-pc\object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_fp_aug1.mtl
# 70,d:\dx3dlc-pc\object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_fp_aug2.mtl
# 71,d:\dx3dlc-pc\object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_glass.mtl
# 72,d:\dx3dlc-pc\object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_goatee.mtl
# 73,d:\dx3dlc-pc\object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_hairs.mtl
# 74,d:\dx3dlc-pc\object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_head.mtl
# 75,d:\dx3dlc-pc\object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_pants.mtl
# 76,d:\dx3dlc-pc\object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_torso.mtl
# 77,cdcrendermodeldata_object\characters\base\mesh\adam_jensen\adam_jensen_cinematic.default
# 78,object/characters/cinematic/_basecinenpc/cinematic_adamjensen_commando/cinematic_adamjensen_commando
# 79,object/characters/cinematic/_basecinenpc/template_cineactorintro_highres/template_cineactorintro_highres
# 80,modeldata_cinematic_adamjensen_commando_adam_jensen_cinematic.default
# 81,d:\dx3dlc-pc\object\characters\cinematic\_basecinenpc\cinematic_adamjensen_commando.dat
# 82,d:\dx3dlc-pc\object\characters\cinematic\_basecinenpc\cinematic_adamjensen_commando.datfxi
# 83,d:\dx3dlc-pc\object\characters\cinematic\_basecinenpc\cinematic_adamjensen_commando.datdfx
# 84,d:\dx3dlc-pc\object\effects\fx_art\materials\pt_addglow_glow03.mtl
# 85,d:\dx3dlc-pc\object\effects\fx_art\materials\pt_alpha_ring_distort05.mtl
# 86,d:\dx3dlc-pc\object\effects\fx_art\materials\pt_alpha_smoke07.mtl
# 87,d:\dx3dlc-pc\object\effects\fx_art\materials\pt_alpha_smoke08_soft.mtl
# 88,d:\dx3dlc-pc\object\effects\fx_art\materials\pt_alpha_waterdropletaa.mtl
# 89,d:\dx3dlc-pc\object\effects\fx_art\materials\pt_alpha_waterdropletb.mtl
# 90,d:\dx3dlc-pc\object\effects\fx_art\materials\pt_mul_pt_droplets_2x2.mtl
# 91,uberobject\default
# 92,uberobject\default.anim
# 93,d:\dx3dlc-pc\art\material_library\panchaea\pan_bleu_paralax_a.mtl
# 94,d:\dx3dlc-pc\art\material_library\panchaea\pan_noir_paralax_a.mtl
# 95,game/script/game/game/disturbance
# 96,game/script/game/game/tvshow
# 97,game/script/game/game/uberobjectbase
# 98,game/script/game/game/uberobjectcommand
# 99,game/script/game/game/uberobjectevent
# 100,game/script/game/game/uberobjectquery
# 101,game/script/game/game/uberobjectsectionid
# 102,d:\dx3dlc-pc\imf\imf_props\imf_vehicule\pod_cryogenic_a\art\materials\pod_signs_a.mtl
# 103,object/props/_base/_master/master_uberobject/master_uberobject/master_uberobject
# 104,d:\dx3dlc-pc\object\props\cutscenes\shanghai\sha_city_port_2a\the_pod\art\materials\cryogenic_pod_base_a.mtl
# 105,d:\dx3dlc-pc\object\props\cutscenes\shanghai\sha_city_port_2a\the_pod\art\materials\cryogenic_pod_details_a.mtl
# 106,d:\dx3dlc-pc\object\props\cutscenes\shanghai\sha_city_port_2a\the_pod\art\materials\pod_cryogenic_lcdglow.mtl
# 107,cdcrendermodeldata_object\props\cutscenes\shanghai\sha_city_port_2a\the_pod\the_pod.default
# 108,object/props/cutscenes/shanghai/sha_city_port_2a/the_pod/the_pod/the_pod
# 109,d:\dx3dlc-pc\object\props\cutscenes\shanghai\sha_city_port_2a\the_pod\the_pod.dat
# 110,d:\dx3dlc-pc\object\props\cutscenes\shanghai\sha_city_port_2a\the_pod\the_pod.datfxi
# 111,modeldata_the_pod_the_pod.default
# 112,admd://d:\dx3dlc-pc\area\scenarios\scn_global_light_conv\overlays\s_scn_global_light_conv_sin_omega__masterunit
# 113,d:\dx3dlc-pc\area\scenarios\scn_global_light_conv\overlays\s_scn_global_light_conv_sin_omega__masterunit.dat
# 114,area/scenarios/scn_global_light_conv/overlays/s_scn_global_light_conv_sin_omega__masterunit/s_scn_global_light_conv_sin_omega__masterunit
# 115,admd://d:\dx3dlc-pc\area\scenarios\scn_global_light_conv\overlays\s_scn_global_light_conv_sin_omega_exterior
# 116,d:\dx3dlc-pc\area\scenarios\scn_global_light_conv\overlays\s_scn_global_light_conv_sin_omega_exterior.dat
# 117,area/scenarios/scn_global_light_conv/overlays/s_scn_global_light_conv_sin_omega_exterior/s_scn_global_light_conv_sin_omega_exterior
# 118,admd://d:\dx3dlc-pc\area\scenarios\scn_global_light_conv\overlays\s_scn_global_light_conv_sin_omega_lab_biomec
# 119,d:\dx3dlc-pc\area\scenarios\scn_global_light_conv\overlays\s_scn_global_light_conv_sin_omega_lab_biomec.dat
# 120,area/scenarios/scn_global_light_conv/overlays/s_scn_global_light_conv_sin_omega_lab_biomec/s_scn_global_light_conv_sin_omega_lab_biomec
# 121,d:\dx3dlc-pc\art\materials\enginex\defrndobj\deferred_fast_omni_90.mtl
# 122,d:\dx3dlc-pc\art\materials\enginex\defrndobj\deferred_spot_rimlight.mtl
# 123,d:\dx3dlc-pc\object\meta_object\enginex\deferred\fast\deferred_fast_omni_90d\deferred_fast_omni_90d.dat
# 124,d:\dx3dlc-pc\object\meta_object\enginex\deferred\fast\deferred_fast_omni_90d\deferred_fast_omni_90d.datfxi
# 125,modeldata_deferred_fast_omni_90d_fastomni90_deficon.engine
# 126,object/meta_object/enginex/deferred/fast/deferred_fast_omni_90d/deferred_fast_omni_90d/deferred_fast_omni_90d
# 127,d:\dx3dlc-pc\object\meta_object\enginex\deferredrenderobj\art\materials\defrndm.mtl
# 128,cdcrendermodeldata_object\meta_object\enginex\deferredrenderobj\fastomni90_deficon.engine
# 129,d:\dx3dlc-pc\object\meta_object\enginex\deferred\fast\deferred_spot_rimlight\deferred_spot_rimlight.dat
# 130,d:\dx3dlc-pc\object\meta_object\enginex\deferred\fast\deferred_spot_rimlight\deferred_spot_rimlight.datfxi
# 131,modeldata_deferred_spot_rimlight_spotrimlight_deficon.engine
# 132,cdcrendermodeldata_object\meta_object\enginex\deferredrenderobj\spotrimlight_deficon.engine
# 133,admd://d:\dx3dlc-pc\area\scenarios\scn_global_light_conv\overlays\s_scn_global_light_conv_sin_omega_lab_gen
# 134,d:\dx3dlc-pc\area\scenarios\scn_global_light_conv\overlays\s_scn_global_light_conv_sin_omega_lab_gen.dat
# 135,area/scenarios/scn_global_light_conv/overlays/s_scn_global_light_conv_sin_omega_lab_gen/s_scn_global_light_conv_sin_omega_lab_gen
# 136,d:\dx3dlc-pc\art\materials\enginex\defrndobj\deferred_fast_spot_90.mtl
# 137,d:\dx3dlc-pc\art\materials\enginex\defrndobj\volspherem.mtl
# 138,d:\dx3dlc-pc\object\meta_object\enginex\deferred\fast\deferred_fast_spot_90d\deferred_fast_spot_90d.dat
# 139,d:\dx3dlc-pc\object\meta_object\enginex\deferred\fast\deferred_fast_spot_90d\deferred_fast_spot_90d.datfxi
# 140,modeldata_deferred_fast_spot_90d_fastspot90_deficon.engine
# 141,cdcrendermodeldata_object\meta_object\enginex\deferredrenderobj\fastspot90_deficon.engine
# 142,modeldata_deferredvolcoronas_corona_deficon.engine
# 143,d:\dx3dlc-pc\object\meta_object\enginex\deferredvolcoronas\deferredvolcoronas.dat
# 144,d:\dx3dlc-pc\object\meta_object\enginex\deferredvolcoronas\deferredvolcoronas.datfxi
# 145,cdcrendermodeldata_object\meta_object\enginex\deferredrenderobj\corona_deficon.engine
# 146,object/meta_object/enginex/deferredvolcoronas/deferredvolcoronas/deferredvolcoronas
# 147,admd://d:\dx3dlc-pc\area\scenarios\scn_global_preorder_premiumpack\overlays\s_scn_global_preorder_premiumpack_sin_omega__masterunit
# 148,d:\dx3dlc-pc\area\scenarios\scn_global_preorde

# %% [markdown]
# # Unidentified file: b9098414
# Filenames for anim fragments maybe

# %%
print(dict(missing)[0xb9098414].decode("utf-8")[:10000])
# Out:
# 6,5899
# 1,d:\dx3dlc-pc\object\projectiles\thrownproj\thrownproj_remote_detonated\ani\idle_free_30_1_0_0_0_0_-1
# 2,d:\dx3dlc-pc\object\pickups\equip\base\weapon_common\ani\idle_free_30_1_0_0_0_0_-1
# 3,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpm_idle_free_30_1_0_0_0_0_0
# 4,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_aim_free_30_1_0_1_1_0_2
# 5,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_aim_free_30_1_0_2_2_0_-1
# 6,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_aim_free_30_1_0_2_2_0_2
# 7,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_aim_free_30_1_0_3_3_0_2
# 8,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_aim_free_30_1_0_4_4_0_5
# 9,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_aim_free_30_1_0_5_5_0_-1
# 10,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_aim_free_30_1_0_5_5_0_5
# 11,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_aim_free_30_1_0_6_6_0_5
# 12,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_crouchjump_free_30_1_0_0_3_0_-1
# 13,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_crouchjump_free_30_1_0_56_0_0_-1
# 14,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_crouchjump_free_30_1_0_9_54_0_-1
# 15,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_crouchrun_free_30_1_0_0_0_0_-1
# 16,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_crouchwalk_free_30_1_0_0_0_0_-1
# 17,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_draw_free_30_0_0_1_0_0_0
# 18,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_fire_free_30_0_0_1_0_0_0
# 19,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_holster_free_30_1_0_0_0_0_0
# 20,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_jump_free_30_1_0_0_3_0_-1
# 21,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_jump_free_30_1_0_56_0_0_-1
# 22,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_jump_free_30_1_0_9_54_0_-1
# 23,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_reload_free_30_0_0_0_0_0_0
# 24,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_run_free_30_1_0_0_0_0_-1
# 25,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_sprint_free_30_1_0_0_0_0_-1
# 26,d:\dx3dlc-pc\animation\game\p\cbt\doublebarrelshotgun\wpn_walk_free_30_1_0_0_0_0_-1
# 27,d:\dx3dlc-pc\animation\game\p\cbt\pistol\wpn_dryfire_free_30_1_0_0_0_0_0
# 28,d:\dx3dlc-pc\animation\game\p\cbt\rifle\wpn_draw2_free_30_0_0_1_0_0_0
# 29,d:\dx3dlc-pc\animation\game\p\cbt\rifle\wpn_grenade_free_30_1_0_0_0_0_0
# 30,d:\dx3dlc-pc\animation\game\p\cbt\rifle\wpn_holster_free_30_1_0_1_0_0_0
# 31,d:\dx3dlc-pc\animation\game\p\cbt\rifle\wpn_quickdraw_free_30_1_0_1_0_0_0
# 32,d:\dx3dlc-pc\animation\game\p\cbt\rifle\wpn_weaponlag_free_30_1_0_1_1_0_2
# 33,d:\dx3dlc-pc\animation\game\p\cbt\rifle\wpn_weaponlag_free_30_1_0_3_3_0_2
# 34,d:\dx3dlc-pc\animation\game\p\cbt\rifle\wpn_weaponlag_free_30_1_0_4_4_0_2
# 35,d:\dx3dlc-pc\animation\game\p\cbt\rifle\wpn_weaponlag_free_30_1_0_5_5_0_2
# 36,d:\dx3dlc-pc\animation\game\p\cbt\shotgun\wpn_ironsight_crouchwalk_free_30_1_0_0_0_0_-1
# 37,d:\dx3dlc-pc\animation\game\p\cbt\shotgun\wpn_ironsight_fire_free_30_0_0_2_0_0_0
# 38,d:\dx3dlc-pc\animation\game\p\cbt\shotgun\wpn_ironsight_free_30_1_0_1_1_0_2
# 39,d:\dx3dlc-pc\animation\game\p\cbt\shotgun\wpn_ironsight_free_30_1_0_2_2_0_-1
# 40,d:\dx3dlc-pc\animation\game\p\cbt\shotgun\wpn_ironsight_free_30_1_0_2_2_0_2
# 41,d:\dx3dlc-pc\animation\game\p\cbt\shotgun\wpn_ironsight_free_30_1_0_3_3_0_2
# 42,d:\dx3dlc-pc\animation\game\p\cbt\shotgun\wpn_ironsight_free_30_1_0_4_4_0_5
# 43,d:\dx3dlc-pc\animation\game\p\cbt\shotgun\wpn_ironsight_free_30_1_0_5_5_0_-1
# 44,d:\dx3dlc-pc\animation\game\p\cbt\shotgun\wpn_ironsight_free_30_1_0_5_5_0_5
# 45,d:\dx3dlc-pc\animation\game\p\cbt\shotgun\wpn_ironsight_free_30_1_0_6_6_0_5
# 46,d:\dx3dlc-pc\animation\game\p\cbt\shotgun\wpn_ironsight_walk_free_30_1_0_0_0_0_-1
# 47,d:\dx3dlc-pc\animation\game\p\cov\cov_cameraidle_free_30_1_0_0_0_0_0
# 48,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\blindfire_free_30_0_0_0_0_0_0
# 49,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_crouchcornering_inside90_free_30_1_0_0_0_0_-1
# 50,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_crouchcornering_outside90_free_30_1_0_0_0_0_-1
# 51,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_crouchdive_free_30_1_0_0_0_0_-1
# 52,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_crouchreload_free_30_1_0_0_0_0_-1
# 53,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_crouchrunforward_free_30_1_0_0_0_0_-1
# 54,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_crouchswap_free_35_1_0_0_0_0_-1
# 55,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_crouchwalkforward_free_30_1_0_0_0_0_-1
# 56,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_crouchwalkreload_free_30_0_0_0_0_0_-1
# 57,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_defendreload_free_30_1_0_0_0_0_0
# 58,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_101_101_0_-1
# 59,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_102_102_0_-1
# 60,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_103_103_0_-1
# 61,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_104_104_0_-1
# 62,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_105_105_0_-1
# 63,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_106_106_0_-1
# 64,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_107_107_0_-1
# 65,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_108_108_0_-1
# 66,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_109_109_0_-1
# 67,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_111_111_0_-1
# 68,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_112_112_0_-1
# 69,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_113_113_0_-1
# 70,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_114_114_0_-1
# 71,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_115_115_0_-1
# 72,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_116_116_0_-1
# 73,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_117_117_0_-1
# 74,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_118_118_0_-1
# 75,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_119_119_0_-1
# 76,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_11_11_0_-1
# 77,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_121_121_0_-1
# 78,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_122_122_0_-1
# 79,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_123_123_0_-1
# 80,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_124_124_0_-1
# 81,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_125_125_0_-1
# 82,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_126_126_0_-1
# 83,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_127_127_0_-1
# 84,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_128_128_0_-1
# 85,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_129_129_0_-1
# 86,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_12_12_0_-1
# 87,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_131_131_0_-1
# 88,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_132_132_0_-1
# 89,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_133_133_0_-1
# 90,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_134_134_0_-1
# 91,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_135_135_0_-1
# 92,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_136_136_0_-1
# 93,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_137_137_0_-1
# 94,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_138_138_0_-1
# 95,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_139_139_0_-1
# 96,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_13_13_0_-1
# 97,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_141_141_0_-1
# 98,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_142_142_0_-1
# 99,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_143_143_0_-1
# 100,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_144_144_0_-1
# 101,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_145_145_0_-1
# 102,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_146_146_0_-1
# 103,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_147_147_0_-1
# 104,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_148_148_0_-1
# 105,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_149_149_0_-1
# 106,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_14_14_0_-1
# 107,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_151_151_0_-1
# 108,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_152_152_0_-1
# 109,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_153_153_0_-1
# 110,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_154_154_0_-1
# 111,d:\dx3dlc-pc\animation\game\p\cov\doublebarrelshotgun\cov_pose_free_30_1_0_155_155_0_-1
# 112,d:\dx3dlc-pc\animation\game\p\cov\doublebarre

# %% [markdown]
# # Unidentified file: b9dd84ae
# I'd have thought everyone uses utf-8 these days, but there is one line here that goes `video\scaleform\sharedtextures\credits\35_février2009` where the é is encoded as hex 0xE9, which is how ISO 8859-1 does it.
#
# This looks very much like a list of texture filenames before they got converted into the final formats.
# Might be interesting to see if there is an unexplained id value close to the material or texture files that lines up with this list.

# %%
# print(dict(missing)[0xb9dd84ae].decode("utf-8"))
print(dict(missing)[0xb9dd84ae].decode("latin1")[:10000])
# Out:
# 6,2667
# 1,art\texture_library\cube_map\det_city_sarif_cube
# 2,art\textures\default_mat_txt\flatmask
# 3,art\textures\default_mat_txt\flatnormal
# 4,art\textures\default_mat_txt\flatwhite
# 5,cdc\assets\textures\dummyblack
# 6,object\characters\base\mesh\_kit_systems_\eyes\adam_eye|d
# 7,object\characters\base\mesh\_kit_systems_\eyes\eyes_n|n
# 8,object\characters\base\mesh\_shared_parts\eye\textures\eye_lens_d
# 9,object\characters\base\mesh\_shared_parts\eye\textures\eye_new|specdots
# 10,object\characters\base\mesh\_shared_parts\facial_hairs\facial_hairs_males|beards_d
# 11,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_arms_d|d
# 12,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_arms_m|m
# 13,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_arms_n|n
# 14,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_arms_s|s
# 15,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_fp_aug_d
# 16,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_fp_aug_decals
# 17,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_fp_aug_m
# 18,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_fp_aug_n
# 19,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_goatee_d
# 20,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_hairs_d|d
# 21,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_head_d|d
# 22,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_head_m|m
# 23,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_head_n|n
# 24,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_pants_d|d
# 25,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_pants_m|m
# 26,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_pants_n|n
# 27,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_pants_s|s
# 28,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_torso_d|d
# 29,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_torso_m|m
# 30,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_torso_n|n
# 31,object\characters\base\mesh\adam_jensen\art\textures\adam_jensen_torso_s|s
# 32,object\characters\patternsv2\denim_01_n
# 33,object\characters\patternsv2\fabric_02_n
# 34,object\characters\patternsv2\grid_01_n
# 35,object\characters\patternsv2\impact_01_n
# 36,object\characters\patternsv2\leather_02_d
# 37,object\characters\patternsv2\leather_02_s
# 38,object\characters\patternsv2\noise_01_n
# 39,object\characters\patternsv2\skin_01_n
# 40,object\characters\patternsv2\skin_01_s
# 41,object\characters\patternsv2\techfabric_01_s
# 42,object\effects\fx_art\textures\pt_droplets_2x2
# 43,object\effects\fx_art\textures\ring_distort05
# 44,object\effects\fx_art\textures\shapes\pt_blurdot
# 45,object\effects\fx_art\textures\smoke07
# 46,object\effects\fx_art\textures\smoke08
# 47,object\effects\fx_art\textures\waterdropletaa
# 48,object\effects\fx_art\textures\waterdropletb
# 49,art\texture_library\cube_map\adam_cubemap_a|diffuse
# 50,art\texture_library\cube_map\cubemap_conv_generic_b
# 51,art\texture_library\diffuse\template_detail_a_d|diffuse
# 52,art\texture_library\diffuse\verre_a_d|diffuse
# 53,art\texture_library\normal\adam_floor_tiles_a_n|normal
# 54,art\texture_library\normal\template_detail_a_n|normal
# 55,art\texture_library\specular\harv_warning_stripe_a_s
# 56,art\texture_library\specular\metal_b_s|specular
# 57,art\textures\default_mat_txt\default_relfmap
# 58,art\textures\default_mat_txt\flatgrey
# 59,art\textures\default_mat_txt\water_soft1
# 60,imf\imf_props\imf_vehicule\pod_cryogenic_a\art\textures\pod_paralax_inside_a
# 61,imf\imf_props\imf_vehicule\pod_cryogenic_a\art\textures\pod_signs_a
# 62,object\props\cutscenes\shanghai\sha_city_port_2a\the_pod\art\textures\cryogenic_pod_a_d
# 63,object\props\cutscenes\shanghai\sha_city_port_2a\the_pod\art\textures\cryogenic_pod_a_n
# 64,object\lighting\lighttexture\light_grad_basic
# 65,object\meta_object\enginex\deferredrenderobj\art\textures\defrndt
# 66,object\pickups\world\explosives\thrown\thrown_remote_detonated\art\textures\remote_detonated_diffuse
# 67,object\pickups\world\explosives\thrown\thrown_remote_detonated\art\textures\remote_detonated_normal
# 68,object\pickups\world\explosives\thrown\thrown_remote_detonated\art\textures\remote_detonated_s
# 69,art\dlc_01\00_global\lighting\textures\flare\flare_sec_a
# 70,art\textures\basics\greygrid16x16|diffuse
# 71,object\effects\fx_art\textures\bullethit_specific\pt_bloodjet
# 72,object\effects\fx_art\textures\ptalpha_smoke2x2
# 73,object\effects\fx_art\textures\ring05
# 74,object\effects\fx_art\textures\rock02
# 75,object\effects\fx_art\textures\shapes\pt_spark
# 76,object\effects\fx_art\textures\weaponfx\pt_muzzle_frontflame_4x4
# 77,object\effects\fx_art\textures\wood04
# 78,object\meta_object\lensflareandcorona\textures\fadecircle
# 79,art\texture_library\specular\pan_plastic_a_s
# 80,object\pickups\world\ammo\weapon_grenadelauncher_ammo\art\textures\weapon_grenadelauncher_ammo_world
# 81,art\texture_library\specular\fiberglass_a_s
# 82,art\textures\default_mat_txt\defaultspec_128
# 83,object\pickups\world\explosives\mines\unlocking_device\art\textures\aud_diffuse
# 84,object\pickups\world\explosives\mines\unlocking_device\art\textures\aud_normal
# 85,art\textures\default_mat_txt\water\waternormal3
# 86,object\effects\fx_art\textures\blue
# 87,object\effects\fx_art\textures\electric\pt_elecbolts_2x2
# 88,object\effects\fx_art\textures\ptalpha_whispysmoke2x2
# 89,object\effects\fx_art\textures\shapes\pt_square
# 90,object\pickups\world\weapons\weapon_doublebarrelshotgun\art\textures\dbshotgun_world_diffuse
# 91,object\fx\bullet\dx3_gunshells\textures\shell_12gauge_d
# 92,object\fx\bullet\dx3_gunshells\textures\shell_12gauge_n
# 93,object\fx\bullet\dx3_gunshells\textures\shell_12gauge_r
# 94,object\pickups\equip\weapons\weapon_doublebarrelshotgun\art\textures\dbshotgun_decal_mask
# 95,object\pickups\equip\weapons\weapon_doublebarrelshotgun\art\textures\dbshotgun_mod_mask
# 96,object\pickups\equip\weapons\weapon_doublebarrelshotgun\art\textures\dbshotgun_normal_mask
# 97,object\pickups\equip\weapons\weapon_shared\art\textures\weapon_metal_d
# 98,object\pickups\equip\weapons\weapon_shared\art\textures\weapon_wood_a
# 99,art\textures\default_mat_txt\flatnoise
# 100,art\textures\default_mat_txt\laserbeam
# 101,object\pickups\equip\weapons\weapon_shared\art\textures\weapon_metal_e
# 102,object\pickups\equip\weapons\weapon_shared\art\textures\weapon_metal_f
# 103,object\pickups\equip\weapons\weapon_shared\art\textures\weapon_plastic
# 104,object\pickups\equip\weapons\weapon_shared\art\textures\weapon_rubber
# 105,object\pickups\equip\weapons\weapon_shotgun\art\textures\weapon_shotgun_decals_mod
# 106,object\pickups\equip\weapons\weapon_shotgun\art\textures\weapon_shotgun_decals_norm
# 107,object\pickups\equip\weapons\weapon_shotgun\art\textures\weapon_shotgun_mask
# 108,object\pickups\world\weapons\weapon_shotgun\art\textures\shotgun_world_diffuse
# 109,object\pickups\world\weapons\weapon_silencedsniperrifle\art\textures\silenced_sniperrifle_world_diffuse
# 110,art\textures\default_mat_txt\blur_dot|diffuse
# 111,art\textures\default_mat_txt\flatcubemap
# 112,object\effects\fx_art\textures\distortion\ptd_torusring
# 113,object\effects\fx_art\textures\pt_flare
# 114,object\effects\fx_art\textures\weaponfx\pt_muzzle_sideflames_4x1
# 115,object\fx\bullet\dx3_gunshells\textures\shell_10mm_d
# 116,object\fx\bullet\dx3_gunshells\textures\shell_10mm_n
# 117,object\fx\bullet\dx3_gunshells\textures\shell_10mm_r
# 118,object\pickups\equip\weapons\weapon_shared\art\textures\scope_lens_mask|mask
# 119,object\pickups\equip\weapons\weapon_shared\art\textures\scope_lens_n
# 120,object\pickups\equip\weapons\weapon_shared\art\textures\silencers_decals_mask
# 121,object\pickups\equip\weapons\weapon_shared\art\textures\silencers_mod_mask
# 122,object\pickups\equip\weapons\weapon_shared\art\textures\silencers_normal_mask
# 123,object\pickups\equip\weapons\weapon_shared\art\textures\weapon_metal_a
# 124,object\pickups\equip\weapons\weapon_shared\art\textures\weapon_metal_c
# 125,object\pickups\equip\weapons\weapon_silencedsniperrifle\art\textures\silenced_sniperrifle_decals_mask
# 126,object\pickups\equip\weapons\weapon_silencedsniperrifle\art\textures\silenced_sniperrifle_mod_mask
# 127,object\pickups\equip\weapons\weapon_silencedsniperrifle\art\textures\silenced_sniperrifle_normal_mask
# 128,object\props\_base\_shared\textures\sharedgrid001|diffuse
# 129,imf\imf_props\imf_supplies\imf_generic\cigarette_a\textures\cigarette_a|diffuse
# 130,object\pickups\world\explosives\thrown\claymore_ammo\art\textures\claymore_ammo_world_d
# 131,object\pickups\world\explosives\thrown\claymore_ammo\art\textures\claymore_ammo_world_n
# 132,object\pickups\world\consumables\nutrientbar\art\textures\nuterients_a|diffuse
# 133,object\pickups\world\consumables\alcohols\alc_beer_bottle_a\art\textures\beer_bottle_ a|diffuse
# 134,imf\imf_props\imf_supplies\imf_food\bowl_noodle_b\textures\bowl_noodle_b|diffuse
# 135,imf\imf_props\imf_supplies\imf_food\can_softdrink_b\textures\can_softdrink_b|diffuse
# 136,object\props\occupation\portable\lw_cup_coffee_a\art\textures\lw_coffee_cup
# 137,art\texture_library\cube_map\default_cubemap_a
# 138,art\texture_library\normal\snow_c_n|normal
# 139,object\props\occupation\portable\lw_file_nail_a\art\textures\file_nail_a_d
# 140,imf\imf_props\imf_supplies\imf_food\stick_noodles_a\textures\stick_noodles_a|diffuse
# 141,imf\imf_props\imf_supplies\imf_electronic\cellphone_a\textures\cellphone_a|diffuse
# 142,imf\imf_props\imf_supplies\imf_electronic\cellphone_a\textures\cellphone_a|normal
# 143,imf\imf_props\imf_supplies\imf_electronic\cellphone_a\textures\cellphone_a|specular
# 144,object\props\occupation\portable\lw_cellphone_b\art\textures\lw_cellphone_b
# 145,object\props\occupation\portable\lw_cigarette_pack_a\art\textures\lw_ciragette_pack_a_d
# 146,object\props\occupation\portable\lw_lighter_a\art\textures\lw_lighter_a

# %% [markdown]
# # Unidentified file: c246e0cc
# Joint names

# %%
print(dict(missing)[0xc246e0cc].decode("utf-8"))
# Out:
# 1,454
# 1,t
# 2,r
# 3,waistjoint
# 4,r_hipjoint
# 5,r_kneejoint
# 6,r_anklejoint
# 7,r_balljoint
# 8,r_hiprolljoint
# 9,l_hipjoint
# 10,l_kneejoint
# 11,l_anklejoint
# 12,l_balljoint
# 13,l_hiprolljoint
# 14,spine0joint
# 15,spine1joint
# 16,spine2joint
# 17,neck0joint
# 18,neckrolljoint
# 19,headjoint
# 20,jawjoint
# 21,tongue1joint
# 22,tongue0joint
# 23,c_lowerlipjoint
# 24,r_lowerlipjoint
# 25,r_lowerlip2joint
# 26,l_lowerlipjoint
# 27,l_lowerlip2joint
# 28,c_chinjoint
# 29,c_btmchinjoint
# 30,r_lowercheekjoint
# 31,r_midjawjoint
# 32,r_chinjoint
# 33,l_lowercheekjoint
# 34,l_midjawjoint
# 35,l_chinjoint
# 36,r_lowermouthjoint
# 37,l_lowermouthjoint
# 38,r_outjawjoint
# 39,l_outjawjoint
# 40,c_uppermouthjoint
# 41,c_upperlipjoint
# 42,l_upperlidjoint
# 43,l_eyejoint
# 44,r_eyejoint
# 45,r_upperlidjoint
# 46,c_browjoint
# 47,c_forheadjoint
# 48,c_nosetopjoint
# 49,c_nosetipjoint
# 50,r_forheadtopjoint
# 51,r_outtermouthjoint
# 52,r_outtercheekjoint
# 53,r_nosesneerjoint
# 54,r_topcheekjoint
# 55,r_incheekjoint
# 56,r_nosewrinclejoint
# 57,r_eyelidtopjoint
# 58,r_eyeoutjoint
# 59,r_eyelid2joint
# 60,r_eyelid1joint
# 61,r_eyeinjoint
# 62,r_upperlipjoint
# 63,r_cornerlipjoint
# 64,r_nosejoint
# 65,r_uppercheekjoint
# 66,r_brow0joint1
# 67,r_brow1joint
# 68,r_brow2joint
# 69,r_upperlip2joint
# 70,r_cornermouthjoint
# 71,r_uppermouthjoint
# 72,r_foreheadjoint
# 73,l_forheadtopjoint
# 74,l_outtermouthjoint
# 75,l_outtercheekjoint
# 76,l_nosesneerjoint
# 77,l_topcheekjoint
# 78,l_incheekjoint
# 79,l_nosewrinclejoint
# 80,l_eyelidtopjoint
# 81,l_eyeoutjoint
# 82,l_eyelid2joint
# 83,l_eyelid1joint
# 84,l_eyeinjoint
# 85,l_upperlipjoint
# 86,l_cornerlipjoint
# 87,l_nosejoint
# 88,l_uppercheekjoint
# 89,l_brow0joint1
# 90,l_brow1joint
# 91,l_brow2joint
# 92,l_upperlip2joint
# 93,l_cornermouthjoint
# 94,l_uppermouthjoint
# 95,l_foreheadjoint
# 96,l_claviclejoint
# 97,l_shoulderjoint
# 98,l_shoulderrolljoint
# 99,l_shoulderroll_2_joint
# 100,l_elbowjoint
# 101,l_armrolljoint
# 102,l_wristjoint
# 103,l_pinky0joint
# 104,l_pinky1joint
# 105,l_pinky2joint
# 106,l_ring0joint
# 107,l_ring1joint
# 108,l_ring2joint
# 109,l_middle0joint
# 110,l_middle1joint
# 111,l_middle2joint
# 112,l_index0joint
# 113,l_index1joint
# 114,l_index2joint
# 115,l_thumb0joint
# 116,l_thumb1joint
# 117,l_thumb2joint
# 118,l_handattach
# 119,l_antigrave_0_joint
# 120,l_antigrave_1_joint
# 121,l_forearmtopjoint
# 122,l_bladejoint
# 123,l_forearmbackjoint
# 124,l_forearmfrontjoint
# 125,r_claviclejoint
# 126,r_shoulderjoint
# 127,r_shoulderrolljoint
# 128,r_shoulderroll_2_joint
# 129,r_elbowjoint
# 130,r_armrolljoint
# 131,r_wristjoint
# 132,r_pinky0joint
# 133,r_pinky1joint
# 134,r_pinky2joint
# 135,r_ring0joint
# 136,r_ring1joint
# 137,r_ring2joint
# 138,r_middle0joint
# 139,r_middle1joint
# 140,r_middle2joint
# 141,r_index0joint
# 142,r_index1joint
# 143,r_index2joint
# 144,r_thumb0joint
# 145,r_thumb1joint
# 146,r_thumb2joint
# 147,r_handattach
# 148,r_forearmtopjoint
# 149,r_bladejoint
# 150,r_forearmbackjoint
# 151,r_forearmfrontjoint
# 152,r_antigrave_0_joint
# 153,r_antigrave_1_joint
# 154,cam_parent
# 155,cam
# 156,gun_parent
# 157,gun
# 158,gunlef
# 159,gunrite
# 160,cameradof
# 161,camerafov
# 162,timecontrol
# 163,doublebarrel_joint
# 164,ejecter_joint
# 165,slug_01_joint
# 166,slug_02_joint
# 167,lock_joint
# 168,l_brow0joint
# 169,l_lowerlidjoint
# 170,chinjoint
# 171,r_brow0joint
# 172,r_lowerlidjoint
# 173,l_antigravebladejoint
# 174,l_trijoint
# 175,l_antigravjoint
# 176,l_bicepjoint
# 177,r_wristtopaugjoint
# 178,r_wristbtmaugjoint
# 179,r_antigravebladejoint
# 180,r_trijoint
# 181,r_antigravjoint
# 182,r_bicepjoint
# 183,t_pistol
# 184,joint_pistol_trigger
# 185,joint_pistol_magazine
# 186,joint_pistol_hammer
# 187,joint_pistol_slidegroup
# 188,base_handle
# 189,handlelock
# 190,joint_to_handle
# 191,handle
# 192,magazine
# 193,cocking_handle
# 194,trigger
# 195,frame
# 196,chamber
# 197,wheel
# 198,joint_magazin
# 199,joint_reload
# 200,joint_reloadbutton
# 201,centerofview
# 202,t_heavyrifle
# 203,joint_reloaddoor
# 204,joint_mag
# 205,joint_cockinghandle
# 206,joint_barrel
# 207,joint_handle
# 208,joint_barrel_motor
# 209,plane_joint
# 210,covjoint
# 211,slide_joint
# 212,ring_joint
# 213,mag_joint
# 214,goupille_joint
# 215,joint_pistol_magazine1
# 216,joint_pistol_magazine2
# 217,r_toenub
# 218,l_toenub
# 219,l_pinkynub
# 220,l_ringnub
# 221,l_middlenub
# 222,l_indexnub
# 223,l_thumbnub
# 224,r_pinkynub
# 225,r_ringnub
# 226,r_middlenub
# 227,r_indexnub
# 228,r_thumbnub
# 229,base_joint
# 230,tip_joint
# 231,master_joint
# 232,yaw_joint
# 233,pitch_joint
# 234,lightstage_1_joint
# 235,lightstage_2_joint
# 236,lightstage_3_joint
# 237,lightstage_4_joint
# 238,camerabone
# 239,terminal_screen_left
# 240,terminal_screen_right
# 241,screen_base
# 242,screen__base_right
# 243,screen_base_left
# 244,screen__top_right
# 245,screen__top_left
# 246,screen_top
# 247,right_door
# 248,down_arm1_joint
# 249,down_arm2_joint
# 250,door_joint
# 251,up_arm1_joint
# 252,up_arm2_joint
# 253,r1
# 254,r2
# 255,r3
# 256,r4
# 257,bottom_jt
# 258,up_jt
# 259,bodyjoint
# 260,hipjoint_l
# 261,kneejoint_l
# 262,reartrainjoint_l
# 263,lowerpistonbackjoint_l
# 264,frontwheelcenterjoint_l
# 265,frontwheelpivotjoint_l
# 266,lowerpistonfrontjoint_l
# 267,upperpistonbottomjoint_l
# 268,wheelstabjoint_l
# 269,upperpistontopjoint_l
# 270,hipjoint_r
# 271,kneejoint_r
# 272,reartrainjoint_r
# 273,lowerpistonbackjoint_r
# 274,frontwheelcenterjoint_r
# 275,frontwheelpivotjoint_r
# 276,lowerpistonfrontjoint_r
# 277,upperpistonbottomjoint_r
# 278,wheelstabjoint_r
# 279,upperpistontopjoint_r
# 280,headparentjoint
# 281,beltjoint
# 282,scannerjoint
# 283,s1
# 284,s2
# 285,n
# 286,h
# 287,j
# 288,tg1
# 289,tg2
# 290,mll
# 291,rll
# 292,lll
# 293,lck1
# 294,lb3
# 295,lb2
# 296,lb1
# 297,rb1
# 298,rb2
# 299,rb3
# 300,leye
# 301,leyelid
# 302,reye
# 303,reyelid
# 304,rck1
# 305,nose
# 306,rul
# 307,rcrn
# 308,mul
# 309,mul2
# 310,lul
# 311,lcrn
# 312,pt1
# 313,pt2
# 314,pt3
# 315,pt4
# 316,pt5
# 317,pt6
# 318,pt7
# 319,pt8
# 320,pt9
# 321,pt10
# 322,lck2
# 323,rck2
# 324,pt21
# 325,pt22
# 326,pt23
# 327,pt24
# 328,pt25
# 329,pt26
# 330,pt27
# 331,pt28
# 332,pt29
# 333,pt30
# 334,fringe
# 335,lbr1
# 336,lbr2
# 337,rbr1
# 338,rbr2
# 339,lc
# 340,ls
# 341,le
# 342,lw
# 343,lpf1
# 344,lpf2
# 345,lpf3
# 346,lmf1
# 347,lmf2
# 348,lmf3
# 349,lrf1
# 350,lrf2
# 351,lrf3
# 352,lpk1
# 353,lpk2
# 354,lpk3
# 355,lth1
# 356,lth2
# 357,lgp
# 358,lw_help
# 359,ls_help
# 360,rc
# 361,rs
# 362,re
# 363,rw
# 364,rpf1
# 365,rpf2
# 366,rpf3
# 367,rmf1
# 368,rmf2
# 369,rmf3
# 370,rrf1
# 371,rrf2
# 372,rrf3
# 373,rpk1
# 374,rpk2
# 375,rpk3
# 376,rth1
# 377,rth2
# 378,rgp
# 379,rw_help
# 380,rs_help
# 381,w
# 382,lh
# 383,ln
# 384,la
# 385,lt
# 386,rh
# 387,rn
# 388,ra
# 389,rt
# 390,snaps
# 391,offset
# 392,canon_left
# 393,canon_right
# 394,wheel_joint
# 395,string_joint
# 396,string_hook_joint
# 397,left_basemetal_piece_downjoint
# 398,left_metal_piece_joint
# 399,left_metal_bend_high_joint
# 400,left_metal_piece_wheel_joint
# 401,left_metal_bend_low_joint
# 402,arrow
# 403,right_basemetal_piece_downjoint
# 404,right_metal_piece_joint
# 405,right_metal_bend_high_joint
# 406,right_metal_piece_wheel_joint
# 407,right_metal_bend_low_joint
# 408,t|arrow
# 409,joint_scope
# 410,joint_beam_start
# 411,joint_beam_stop
# 412,front_slide_pivot_joint
# 413,front_slide_joint
# 414,back_slide_joint
# 415,left_side_slide
# 416,trigger_joint
# 417,magazine_joint
# 418,moving_base_joint
# 419,rotating_piece_joint
# 420,small_moving_base_joint
# 421,lowslide_tip_joint
# 422,low_slide_base_joint
# 423,t|left_side_slide
# 424,right_side_slide
# 425,joint_canon
# 426,joint_caroussel
# 427,joint_hammer
# 428,joint_cap
# 429,magazines_door_joint
# 430,lasertip
# 431,start_joint
# 432,end_joint
# 433,barrel_joint
# 434,cartridge_joint
# 435,dart_joint
# 436,barrelcap_joint
# 437,ventdoors_joint
# 438,button_joint
# 439,canon
# 440,joint1
# 441,screen_right
# 442,screen_left
# 443,camera_door
# 444,magazin
# 445,missile
# 446,t|missile
# 447,reload_joint
# 448,fronttop_joint
# 449,frontleft_joint
# 450,frontright_joint
# 451,backtop_joint
# 452,backleft_joint
# 453,backright_joint
# 454,r_shoulderrolr_2_joint

# %% [markdown]
# # Unidentified file: ea6cb8a4
# Sound names

# %%
print(dict(missing)[0xea6cb8a4].decode("utf-8")[:10000])
# Out:
# 3,1851
# 1,foley\object\physic\barrel_plastic_slide_01
# 2,foley\object\physic\remotedetonategel\remotedetonategel_01
# 3,foley\object\physic\remotedetonategel\remotedetonategel_02
# 4,foley\object\physic\remotedetonategel\remotedetonategel_03
# 5,foley\pickup\genericpickup
# 6,foley\object\squib\grenades\feedback_01
# 7,foley\object\squib\grenades\feedback_02
# 8,foley\object\squib\grenades\feedback_03
# 9,foley\object\squib\grenades\grenade_frag_august_02
# 10,foley\object\squib\grenades\reverse_whoosh
# 11,foley\pickup\ammo\sniper\pickup_ammo_sniper_01
# 12,foley\pickup\ammo\sniper\pickup_ammo_sniper_02
# 13,foley\pickup\ammo\sniper\pickup_ammo_sniper_03
# 14,foley\object\physic\grenade_frag\frag_grenade_bounce_01
# 15,foley\object\physic\grenade_frag\frag_grenade_bounce_02
# 16,foley\object\physic\grenade_frag\frag_grenade_roll
# 17,foley\object\squib\aud\aud_beep_01
# 18,foley\object\squib\aud\aud_buildup_01
# 19,foley\object\squib\aud\aud_explosion_01
# 20,foley\object\physic\weapon\gundrop_bounce
# 21,foley\pickup\weapons\shotgun\pickupshotgun_01
# 22,foley\pickup\weapons\shotgun\pickupshotgun_02
# 23,foley\pickup\weapons\shotgun\pickupshotgun_03
# 24,foley\impacts\bodyimpact\bodyimpact_01
# 25,foley\impacts\bodyimpact\bodyimpact_02
# 26,foley\impacts\bodyimpact\bodyimpact_03
# 27,foley\movement\cloth_suit\swipe_fast\clothsuit_swipe_fast_01
# 28,foley\movement\cloth_suit\swipe_fast\clothsuit_swipe_fast_02
# 29,foley\movement\cloth_suit\swipe_fast\clothsuit_swipe_fast_03
# 30,foley\movement\cloth_suit\swipe_fast\clothsuit_swipe_fast_04
# 31,foley\movement\cloth_suit\swipe_fast\clothsuit_swipe_fast_05
# 32,foley\movement\cloth_suit\swipe_fast\clothsuit_swipe_fast_06
# 33,foley\movement\cloth_suit\swipe_fast\clothsuit_swipe_fast_07
# 34,foley\movement\cloth_suit\swipe_fast\clothsuit_swipe_fast_08
# 35,foley\movement\cloth_suit\swipe_slow\clothsuit_swipe_slow_01
# 36,foley\movement\cloth_suit\swipe_slow\clothsuit_swipe_slow_02
# 37,foley\movement\cloth_suit\swipe_slow\clothsuit_swipe_slow_03
# 38,foley\movement\cloth_suit\swipe_slow\clothsuit_swipe_slow_04
# 39,foley\movement\cloth_suit\swipe_slow\clothsuit_swipe_slow_05
# 40,foley\movement\cloth_suit\swipe_slow\clothsuit_swipe_slow_06
# 41,foley\movement\whoosh\adam_cbt_cover_stand_short_flip_01
# 42,foley\movement\whoosh\adam_cbt_cover_stand_short_flip_02
# 43,foley\movement\whoosh\adam_cbt_cover_stand_short_flip_03
# 44,foley\movement\whoosh\adam_ncbt_cover_stand_short_flip_01
# 45,foley\movement\whoosh\adam_ncbt_cover_stand_short_flip_02
# 46,foley\movement\whoosh\adam_ncbt_cover_stand_short_flip_03
# 47,foley\movement\whoosh\adam_ncbt_cover_stand_short_flip_04
# 48,foley\movement\whoosh\whoosh_slow_01
# 49,foley\movement\whoosh\whoosh_slow_02
# 50,foley\movement\whoosh\whoosh_slow_03
# 51,foley\movement\whoosh\whoosh_slow_04
# 52,foley\movement\whoosh\whoosh_slow_05
# 53,foley\movement\whoosh\whoosh_slow_06
# 54,foley\movement\whoosh\whoosh_slow_07
# 55,foley\weapon\bullet_shell\shotgun\generic\shotgun_generic_bullet_shell_01
# 56,foley\weapon\bullet_shell\shotgun\generic\shotgun_generic_bullet_shell_02
# 57,foley\weapon\bullet_shell\shotgun\generic\shotgun_generic_bullet_shell_03
# 58,foley\weapon\bullet_shell\shotgun\generic\shotgun_generic_bullet_shell_04
# 59,foley\weapon\doublebarrel_shotgun\shotgun_doublebarrell_fire01
# 60,foley\weapon\doublebarrel_shotgun\shotgun_doublebarrell_fire02
# 61,foley\weapon\doublebarrel_shotgun\shotgun_doublebarrell_fire03
# 62,foley\weapon\doublebarrel_shotgun\shotgun_hand_01
# 63,foley\weapon\doublebarrel_shotgun\shotgun_hand_02
# 64,foley\weapon\doublebarrel_shotgun\shotgun_open_hatch
# 65,foley\weapon\doublebarrel_shotgun\shotgun_ready
# 66,foley\weapon\doublebarrel_shotgun\shotgun_safty_off_01
# 67,foley\weapon\doublebarrel_shotgun\shotgun_safty_on_01
# 68,foley\weapon\doublebarrel_shotgun\shotgun_shell_insert
# 69,foley\weapon\doublebarrel_shotgun\shotgun_shell_out
# 70,foley\weapon\pistol\handling\handling_pistol_01
# 71,foley\weapon\pistol\handling\handling_pistol_02
# 72,foley\weapon\pistol\handling\handling_pistol_03
# 73,foley\weapon\pistol\handling\handling_pistol_04
# 74,foley\weapon\pistol\handling\handling_pistol_05
# 75,foley\weapon\pistol\pistol_holster_npc\pistol_holster
# 76,foley\weapon\pistol\pistoldraw_npc\pistol_draw_npc_01
# 77,foley\weapon\pistol\pistoldraw_npc\pistol_draw_npc_02
# 78,foley\weapon\pistol\pistoldraw_npc\pistol_draw_npc_03
# 79,foley\weapon\revolver\handling\revolver_dryfire_a_01
# 80,foley\weapon\revolver\handling\revolver_dryfire_a_02
# 81,foley\weapon\revolver\handling\revolver_dryfire_b_01
# 82,foley\weapon\revolver\handling\revolver_dryfire_b_02
# 83,foley\weapon\rifle\draw\unholster_rifle_01
# 84,foley\weapon\rifle\draw\unholster_rifle_02
# 85,foley\weapon\rifle\draw\unholster_rifle_03
# 86,foley\weapon\rifle\handling\handling_rifle_01
# 87,foley\weapon\rifle\handling\handling_rifle_02
# 88,foley\weapon\rifle\handling\handling_rifle_03
# 89,foley\weapon\rifle\handling\handling_rifle_04
# 90,foley\weapon\rifle\handling\handling_rifle_05
# 91,foley\weapon\shotgun\handling\handling_shotgun_01
# 92,foley\weapon\shotgun\handling\handling_shotgun_02
# 93,foley\weapon\shotgun\handling\handling_shotgun_03
# 94,foley\weapon\shotgun\handling\handling_shotgun_04
# 95,foley\weapon\shotgun\handling\handling_shotgun_05
# 96,foley\weapon\shotgun\sg_cocking_release
# 97,foley\weapon\shotgun\sg_handle_back
# 98,foley\weapon\shotgun\sg_handle_forward
# 99,foley\weapon\shotgun\shotgunfire_upgrade1_01
# 100,foley\weapon\shotgun\shotgunfire_upgrade1_02
# 101,foley\weapon\shotgun\shotgunfire_upgrade1_03
# 102,foley\weapon\shotgun\shotgunfire_upgrade3_01
# 103,foley\weapon\shotgun\shotgunfire_upgrade3_02
# 104,foley\weapon\shotgun\shotgunfire_upgrade3_03
# 105,foley\weapon\sniper_rifle\handling\sniperrifle_handling_move4
# 106,foley\weapon\sniper_rifle\handling\sniperrifle_handling_move5
# 107,foley\weapon\sniper_rifle\handling\sniperrifle_handling_move6
# 108,foley\weapon\sniper_rifle\handling\sniperrifle_handling_move7
# 109,foley\movement\whoosh\adam_cbt_cover_stand_long_dive_01
# 110,foley\movement\whoosh\adam_cbt_cover_stand_long_dive_02
# 111,foley\movement\whoosh\adam_cbt_cover_stand_long_dive_03
# 112,foley\weapon\shotgun\sg_cocking_pull
# 113,foley\weapon\shotgun\sg_mag_in
# 114,foley\weapon\shotgun\sg_mag_out
# 115,foley\weapon\shotgun\shotgunupgraded_stock01
# 116,foley\weapon\shotgun\shotgunupgraded_stock02
# 117,foley\weapon\shotgun\shotgunupgraded_stock03
# 118,foley\weapon\shotgun\shotgunupgraded_upgrade1_01
# 119,foley\weapon\shotgun\shotgunupgraded_upgrade1_02
# 120,foley\weapon\shotgun\shotgunupgraded_upgrade1_03
# 121,foley\weapon\shotgun\shotgunupgraded_upgrade2_01
# 122,foley\weapon\shotgun\shotgunupgraded_upgrade2_02
# 123,foley\weapon\shotgun\shotgunupgraded_upgrade2_03
# 124,foley\weapon\shotgun\shotgunupgraded_upgrade3_01
# 125,foley\weapon\shotgun\shotgunupgraded_upgrade3_02
# 126,foley\weapon\shotgun\shotgunupgraded_upgrade3_03
# 127,foley\pickup\weapons\pistol\pickuppistol_01
# 128,foley\pickup\weapons\pistol\pickuppistol_02
# 129,foley\pickup\weapons\pistol\pickuppistol_03
# 130,foley\weapon\bullet_shell\big\generic\big_generic_bullet_shell_01
# 131,foley\weapon\bullet_shell\big\generic\big_generic_bullet_shell_02
# 132,foley\weapon\bullet_shell\big\generic\big_generic_bullet_shell_03
# 133,foley\weapon\bullet_shell\big\generic\big_generic_bullet_shell_04
# 134,foley\weapon\sniper_rifle\handling\silencedsniper_dropclip_03
# 135,foley\weapon\sniper_rifle\handling\silencedsniper_dropclip_04
# 136,foley\weapon\sniper_rifle\handling\silencedsniperrifle_handling_ejectammo_01
# 137,foley\weapon\sniper_rifle\handling\silencedsniperrifle_handling_ejectammo_02
# 138,foley\weapon\sniper_rifle\handling\silencedsniperrifle_handling_ejectammo_03
# 139,foley\weapon\sniper_rifle\handling\silencedsniperrifle_handling_handhit01
# 140,foley\weapon\sniper_rifle\handling\silencedsniperrifle_handling_hitclip1
# 141,foley\weapon\sniper_rifle\handling\silencedsniperrifle_handling_hitclip2
# 142,foley\weapon\sniper_rifle\handling\silencedsniperrifle_handling_insertclip1
# 143,foley\weapon\sniper_rifle\handling\silencedsniperrifle_handling_pull
# 144,foley\weapon\sniper_rifle\handling\silencedsniperrifle_handling_push
# 145,foley\weapon\sniper_rifle\handling\silencedsniperrifle_handling_removeclip1
# 146,foley\weapon\sniper_rifle\handling\silencedsniperrifle_handling_turn01
# 147,foley\weapon\sniper_rifle\handling\silencedsniperrifle_handling_turn02
# 148,foley\weapon\sniper_rifle\handling\sniperrifle_handling_hand
# 149,foley\weapon\sniper_rifle\handling\sniperrifle_handling_hit
# 150,foley\weapon\sniper_rifle\handling\sniperrifle_handling_land
# 151,foley\weapon\sniper_rifle\handling\sniperrifle_handling_move02
# 152,foley\weapon\sniper_rifle\handling\sniperrifle_handling_move03
# 153,foley\weapon\sniper_rifle\sniperrifle_fire_silencer_01
# 154,foley\weapon\sniper_rifle\sniperrifle_fire_silencer_02
# 155,foley\weapon\sniper_rifle\sniperrifle_fire_silencer_03
# 156,foley\movement\augsuit\augsuit_shuffle_slow_01
# 157,foley\movement\augsuit\augsuit_shuffle_slow_02
# 158,foley\movement\augsuit\augsuit_shuffle_slow_03
# 159,foley\movement\augsuit\augsuit_shuffle_slow_04
# 160,foley\movement\augsuit\augsuit_swipe_fast_01
# 161,foley\movement\augsuit\augsuit_swipe_fast_02
# 162,foley\movement\augsuit\augsuit_swipe_fast_03
# 163,foley\movement\augsuit\augsuit_swipe_fast_04
# 164,character\npc\footsteps\asphalt\fst_npc_scuff_asphalt_01
# 165,character\npc\footsteps\asphalt\fst_npc_scuff_asphalt_02
# 166,foley\movement\cloth_suit\shuffle_slow\clothsuit_shuffle_slow_01
# 167,foley\movement\cloth_suit\shuffle_slow\clothsuit_shuffle_slow_02
# 168,foley\movement\cloth_suit\shuffle_slow\clothsuit_shuffle_slow_03
# 169,foley\movement\cloth_suit\shuffle_slow\clothsuit_shuffle_slow_04
# 170,foley\object\smoking\smoking_exhale_01
# 171,foley\object\smoking\smoking_exhale_02
# 172,foley\object\smoking\smoking_exhale_03
# 173,foley\object\smoking\smoking_inhale_01
# 174,foley\object\smoking\smoking_inhale_02
# 175,foley\object\smoking\smoking_inhale_03
# 176,foley\object\smoking\
